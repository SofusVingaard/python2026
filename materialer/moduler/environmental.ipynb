# %%
import os

# %%
os.environ['api_key'] = '1234Hello_World'

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv('.env')
# Out:
# False

# %%
api_key = os.environ.get('API_TEST')
print(api_key)
# Out:
# None
